# %%
# Install necessary packages
# !pip install -q amplpy ampltools

# Google Colab & AMPL integration
MODULES, LICENSE_UUID = ["coin", 'gurobi', "cplex", "highs", "gokestrel"], "42fc7eb6-69aa-445d-b655-3ad24d836541"
from amplpy import tools
from ampltools import cloud_platform_name, ampl_notebook, register_magics

# Instantiate AMPL object and register magics
if cloud_platform_name() is None:
    ampl = AMPL()  # Use local installation of AMPL
else:
    ampl = tools.ampl_notebook(modules=MODULES, license_uuid=LICENSE_UUID, g=globals())

register_magics(ampl_object=ampl)
# Out:
# Licensed to Bundle #6741.7193 expiring 20241231: INFO 645 Prescriptive Analytics, Prof. Paul Brooks, Virginia Commonwealth University.

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load data from the updated sheets
annual_hours = pd.read_excel("/content/drive/MyDrive/645/realignment_data.xlsx", sheet_name='StoreData1')

annual_trips = pd.read_excel("/content/drive/MyDrive/645/realignment_data.xlsx", sheet_name='StoreData2')

regional_office_data = pd.read_excel("/content/drive/MyDrive/645/realignment_data.xlsx", sheet_name='Regional Office Data')

mileage = pd.read_excel("/content/drive/MyDrive/645/realignment_data.xlsx", sheet_name='TravelData1')

travel_time = pd.read_excel("/content/drive/MyDrive/645/realignment_data.xlsx", sheet_name='TravelData2')

# Replace '--' in travel data with a high value (e.g., 9999)
mileage.replace('--', 9999, inplace=True)
mileage.iloc[:, 1:] = mileage.iloc[:, 1:].apply(pd.to_numeric)

# Replace '--' in travel data with a high value (e.g., 9999)
travel_time.replace('--', 9999, inplace=True)
travel_time.iloc[:, 1:] = travel_time.iloc[:, 1:].apply(pd.to_numeric)

# Process "Annual Hours" sheet (StoreData1)
hours = annual_hours.set_index('Store Name').stack().to_dict()

# Process "Annual Trips" sheet (StoreData2)
trips = annual_trips.set_index('Store Name').stack().to_dict()

# Process "Regional Office Data" sheet
availability = regional_office_data.set_index('Office Name').stack().to_dict()

# Process "Mileage" sheet (TravelData1)
mileage = mileage.set_index('Store Name').stack().to_dict()

# Process "Travel Time" sheet (TravelData2)
traveltime = travel_time.set_index('Store Name').stack().to_dict()

StateMileageRate=0.585
HourlyWage=26
# Out:
# <ipython-input-131-3deddc5566bf>:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   mileage.replace('--', 9999, inplace=True)
# <ipython-input-131-3deddc5566bf>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   travel_time.replace('--', 9999, inplace=True)

# %%
#Print the dictionaries to verify
print("Annual Trips Dictionary:", trips)
print("Hours Required Dictionary:", hours)
print("Regional Office Data Dictionary:", availability)
print("Mileage Dictionary:", mileage)
print("Travel Time Dictionary:", traveltime)
# Out:
# Annual Trips Dictionary: {('Albemarle_County', 'Inventory'): 39, ('Albemarle_County', 'Payroll'): 133, ('Albemarle_County', 'Hiring'): 0, ('Albemarle_County', 'Marketing'): 19, ('Albemarle_County', 'Merchandising'): 5, ('Amherst_County', 'Inventory'): 0, ('Amherst_County', 'Payroll'): 11, ('Amherst_County', 'Hiring'): 0, ('Amherst_County', 'Marketing'): 1, ('Amherst_County', 'Merchandising'): 0, ('Augusta_County', 'Inventory'): 92, ('Augusta_County', 'Payroll'): 91, ('Augusta_County', 'Hiring'): 186, ('Augusta_County', 'Marketing'): 30, ('Augusta_County', 'Merchandising'): 30, ('Buckingham_County', 'Inventory'): 2, ('Buckingham_County', 'Payroll'): 2, ('Buckingham_County', 'Hiring'): 23, ('Buckingham_County', 'Marketing'): 15, ('Buckingham_County', 'Merchandising'): 4, ('Caroline_County', 'Inventory'): 4, ('Caroline_County', 'Payroll'): 17, ('Caroline_County', 'Hiring'): 6, ('Caroline_County', 'Marketing'): 5, ('Caroline_County', 'Merchandising'): 4, ('Charles_City_County', 'Inventory'): 28, ('Charles_City_County', 'Payroll'): 6, ('Charles_City_County', 'Hiring'): 0, ('Charles_City_County', 'Marketing'): 10, ('Charles_City_County', 'Merchandising'): 1, ('Chesterfield_County', 'Inventory'): 55, ('Chesterfield_County', 'Payroll'): 80, ('Chesterfield_County', 'Hiring'): 3, ('Chesterfield_County', 'Marketing'): 12, ('Chesterfield_County', 'Merchandising'): 3, ('City_of_Fredericksburg', 'Inventory'): 19, ('City_of_Fredericksburg', 'Payroll'): 8, ('City_of_Fredericksburg', 'Hiring'): 2, ('City_of_Fredericksburg', 'Marketing'): 0, ('City_of_Fredericksburg', 'Merchandising'): 6, ('City_of_Richmond', 'Inventory'): 41, ('City_of_Richmond', 'Payroll'): 70, ('City_of_Richmond', 'Hiring'): 0, ('City_of_Richmond', 'Marketing'): 0, ('City_of_Richmond', 'Merchandising'): 1, ('Culpeper_County', 'Inventory'): 4, ('Culpeper_County', 'Payroll'): 12, ('Culpeper_County', 'Hiring'): 8, ('Culpeper_County', 'Marketing'): 0, ('Culpeper_County', 'Merchandising'): 5, ('Cumberland_County', 'Inventory'): 7, ('Cumberland_County', 'Payroll'): 8, ('Cumberland_County', 'Hiring'): 19, ('Cumberland_County', 'Marketing'): 2, ('Cumberland_County', 'Merchandising'): 0, ('Dinwiddie_County', 'Inventory'): 35, ('Dinwiddie_County', 'Payroll'): 46, ('Dinwiddie_County', 'Hiring'): 24, ('Dinwiddie_County', 'Marketing'): 14, ('Dinwiddie_County', 'Merchandising'): 5, ('Essex_County', 'Inventory'): 11, ('Essex_County', 'Payroll'): 18, ('Essex_County', 'Hiring'): 24, ('Essex_County', 'Marketing'): 25, ('Essex_County', 'Merchandising'): 1, ('Fauquier_County', 'Inventory'): 22, ('Fauquier_County', 'Payroll'): 36, ('Fauquier_County', 'Hiring'): 40, ('Fauquier_County', 'Marketing'): 19, ('Fauquier_County', 'Merchandising'): 44, ('Fluvanna_County', 'Inventory'): 0, ('Fluvanna_County', 'Payroll'): 24, ('Fluvanna_County', 'Hiring'): 0, ('Fluvanna_County', 'Marketing'): 1, ('Fluvanna_County', 'Merchandising'): 0, ('Goochland_County', 'Inventory'): 1, ('Goochland_County', 'Payroll'): 34, ('Goochland_County', 'Hiring'): 0, ('Goochland_County', 'Marketing'): 13, ('Goochland_County', 'Merchandising'): 2, ('Greene_County', 'Inventory'): 5, ('Greene_County', 'Payroll'): 11, ('Greene_County', 'Hiring'): 6, ('Greene_County', 'Marketing'): 0, ('Greene_County', 'Merchandising'): 2, ('Hanover_County', 'Inventory'): 0, ('Hanover_County', 'Payroll'): 23, ('Hanover_County', 'Hiring'): 6, ('Hanover_County', 'Marketing'): 20, ('Hanover_County', 'Merchandising'): 6, ('Henrico_County', 'Inventory'): 13, ('Henrico_County', 'Payroll'): 71, ('Henrico_County', 'Hiring'): 0, ('Henrico_County', 'Marketing'): 16, ('Henrico_County', 'Merchandising'): 4, ('Hopewell_County', 'Inventory'): 1, ('Hopewell_County', 'Payroll'): 6, ('Hopewell_County', 'Hiring'): 0, ('Hopewell_County', 'Marketing'): 0, ('Hopewell_County', 'Merchandising'): 2, ('James_City_County', 'Inventory'): 30, ('James_City_County', 'Payroll'): 42, ('James_City_County', 'Hiring'): 2, ('James_City_County', 'Marketing'): 0, ('James_City_County', 'Me ...
# Hours Required Dictionary: {('Albemarle_County', 'Inventory'): 460, ('Albemarle_County', 'Payroll'): 771, ('Albemarle_County', 'Hiring'): 0, ('Albemarle_County', 'Marketing'): 96, ('Albemarle_County', 'Merchandising'): 90, ('Amherst_County', 'Inventory'): 2, ('Amherst_County', 'Payroll'): 28, ('Amherst_County', 'Hiring'): 0, ('Amherst_County', 'Marketing'): 8, ('Amherst_County', 'Merchandising'): 0, ('Augusta_County', 'Inventory'): 341, ('Augusta_County', 'Payroll'): 737, ('Augusta_County', 'Hiring'): 2806, ('Augusta_County', 'Marketing'): 260, ('Augusta_County', 'Merchandising'): 65, ('Buckingham_County', 'Inventory'): 46, ('Buckingham_County', 'Payroll'): 40, ('Buckingham_County', 'Hiring'): 408, ('Buckingham_County', 'Marketing'): 84, ('Buckingham_County', 'Merchandising'): 59, ('Caroline_County', 'Inventory'): 13, ('Caroline_County', 'Payroll'): 136, ('Caroline_County', 'Hiring'): 170, ('Caroline_County', 'Marketing'): 10, ('Caroline_County', 'Merchandising'): 55, ('Charles_City_County', 'Inventory'): 90, ('Charles_City_County', 'Payroll'): 26, ('Charles_City_County', 'Hiring'): 0, ('Charles_City_County', 'Marketing'): 40, ('Charles_City_County', 'Merchandising'): 15, ('Chesterfield_County', 'Inventory'): 655, ('Chesterfield_County', 'Payroll'): 343, ('Chesterfield_County', 'Hiring'): 17, ('Chesterfield_County', 'Marketing'): 144, ('Chesterfield_County', 'Merchandising'): 8, ('City_of_Fredericksburg', 'Inventory'): 123, ('City_of_Fredericksburg', 'Payroll'): 64, ('City_of_Fredericksburg', 'Hiring'): 60, ('City_of_Fredericksburg', 'Marketing'): 0, ('City_of_Fredericksburg', 'Merchandising'): 70, ('City_of_Richmond', 'Inventory'): 468, ('City_of_Richmond', 'Payroll'): 264, ('City_of_Richmond', 'Hiring'): 0, ('City_of_Richmond', 'Marketing'): 0, ('City_of_Richmond', 'Merchandising'): 2, ('Culpeper_County', 'Inventory'): 12, ('Culpeper_County', 'Payroll'): 96, ('Culpeper_County', 'Hiring'): 200, ('Culpeper_County', 'Marketing'): 0, ('Culpeper_County', 'Merchandising'): 120, ('Cumberland_County', 'Inventory'): 21, ('Cumberland_County', 'Payroll'): 33, ('Cumberland_County', 'Hiring'): 0, ('Cumberland_County', 'Marketing'): 14, ('Cumberland_County', 'Merchandising'): 0, ('Dinwiddie_County', 'Inventory'): 300, ('Dinwiddie_County', 'Payroll'): 188, ('Dinwiddie_County', 'Hiring'): 480, ('Dinwiddie_County', 'Marketing'): 160, ('Dinwiddie_County', 'Merchandising'): 50, ('Essex_County', 'Inventory'): 63, ('Essex_County', 'Payroll'): 30, ('Essex_County', 'Hiring'): 680, ('Essex_County', 'Marketing'): 200, ('Essex_County', 'Merchandising'): 80, ('Fauquier_County', 'Inventory'): 55, ('Fauquier_County', 'Payroll'): 228, ('Fauquier_County', 'Hiring'): 280, ('Fauquier_County', 'Marketing'): 320, ('Fauquier_County', 'Merchandising'): 40, ('Fluvanna_County', 'Inventory'): 4, ('Fluvanna_County', 'Payroll'): 96, ('Fluvanna_County', 'Hiring'): 0, ('Fluvanna_County', 'Marketing'): 8, ('Fluvanna_County', 'Merchandising'): 0, ('Goochland_County', 'Inventory'): 12, ('Goochland_County', 'Payroll'): 97, ('Goochland_County', 'Hiring'): 0, ('Goochland_County', 'Marketing'): 70, ('Goochland_County', 'Merchandising'): 5, ('Greene_County', 'Inventory'): 36, ('Greene_County', 'Payroll'): 88, ('Greene_County', 'Hiring'): 150, ('Greene_County', 'Marketing'): 0, ('Greene_County', 'Merchandising'): 40, ('Hanover_County', 'Inventory'): 0, ('Hanover_County', 'Payroll'): 184, ('Hanover_County', 'Hiring'): 150, ('Hanover_County', 'Marketing'): 200, ('Hanover_County', 'Merchandising'): 120, ('Henrico_County', 'Inventory'): 96, ('Henrico_County', 'Payroll'): 227, ('Henrico_County', 'Hiring'): 0, ('Henrico_County', 'Marketing'): 84, ('Henrico_County', 'Merchandising'): 78, ('Hopewell_County', 'Inventory'): 7, ('Hopewell_County', 'Payroll'): 36, ('Hopewell_County', 'Hiring'): 0, ('Hopewell_County', 'Marketing'): 0, ('Hopewell_County', 'Merchandising'): 4, ('James_City_County', 'Inventory'): 350, ('James_City_County', 'Payroll'): 127, ('James_City_County', 'Hiring'): 60, ...
# Regional Office Data Dictionary: {('Richmond', 'Inventory'): 5000, ('Richmond', 'Payroll'): 3025, ('Richmond', 'Hiring'): 1225, ('Richmond', 'Marketing'): 1750, ('Richmond', 'Merchandising'): 3675, ('Tappahannock', 'Inventory'): 3400, ('Tappahannock', 'Payroll'): 5550, ('Tappahannock', 'Hiring'): 3250, ('Tappahannock', 'Marketing'): 1200, ('Tappahannock', 'Merchandising'): 1600, ('Warrenton', 'Inventory'): 825, ('Warrenton', 'Payroll'): 2500, ('Warrenton', 'Hiring'): 3375, ('Warrenton', 'Marketing'): 1325, ('Warrenton', 'Merchandising'): 850, ('Staunton', 'Inventory'): 3550, ('Staunton', 'Payroll'): 3450, ('Staunton', 'Hiring'): 9100, ('Staunton', 'Marketing'): 1700, ('Staunton', 'Merchandising'): 1850}
# Mileage Dictionary: {('Albemarle_County', 'Staunton'): 37, ('Albemarle_County', 'Warrenton'): 71, ('Albemarle_County', 'Richmond'): 70, ('Albemarle_County', 'Tappahannock'): 110, ('Amherst_County', 'Staunton'): 56, ('Amherst_County', 'Warrenton'): 9999, ('Amherst_County', 'Richmond'): 120, ('Amherst_County', 'Tappahannock'): 9999, ('Augusta_County', 'Staunton'): 0, ('Augusta_County', 'Warrenton'): 121, ('Augusta_County', 'Richmond'): 9999, ('Augusta_County', 'Tappahannock'): 9999, ('Buckingham_County', 'Staunton'): 66, ('Buckingham_County', 'Warrenton'): 108, ('Buckingham_County', 'Richmond'): 72, ('Buckingham_County', 'Tappahannock'): 9999, ('Caroline_County', 'Staunton'): 9999, ('Caroline_County', 'Warrenton'): 62, ('Caroline_County', 'Richmond'): 42, ('Caroline_County', 'Tappahannock'): 38, ('Charles_City_County', 'Staunton'): 9999, ('Charles_City_County', 'Warrenton'): 9999, ('Charles_City_County', 'Richmond'): 37, ('Charles_City_County', 'Tappahannock'): 72, ('Chesterfield_County', 'Staunton'): 9999, ('Chesterfield_County', 'Warrenton'): 112, ('Chesterfield_County', 'Richmond'): 20, ('Chesterfield_County', 'Tappahannock'): 65, ('City_of_Fredericksburg', 'Staunton'): 111, ('City_of_Fredericksburg', 'Warrenton'): 38, ('City_of_Fredericksburg', 'Richmond'): 59, ('City_of_Fredericksburg', 'Tappahannock'): 47, ('City_of_Richmond', 'Staunton'): 9999, ('City_of_Richmond', 'Warrenton'): 84, ('City_of_Richmond', 'Richmond'): 0, ('City_of_Richmond', 'Tappahannock'): 46, ('Culpeper_County', 'Staunton'): 80, ('Culpeper_County', 'Warrenton'): 25, ('Culpeper_County', 'Richmond'): 89, ('Culpeper_County', 'Tappahannock'): 84, ('Cumberland_County', 'Staunton'): 88, ('Cumberland_County', 'Warrenton'): 108, ('Cumberland_County', 'Richmond'): 53, ('Cumberland_County', 'Tappahannock'): 101, ('Dinwiddie_County', 'Staunton'): 9999, ('Dinwiddie_County', 'Warrenton'): 9999, ('Dinwiddie_County', 'Richmond'): 40, ('Dinwiddie_County', 'Tappahannock'): 85, ('Essex_County', 'Staunton'): 9999, ('Essex_County', 'Warrenton'): 89, ('Essex_County', 'Richmond'): 46, ('Essex_County', 'Tappahannock'): 0, ('Fauquier_County', 'Staunton'): 118, ('Fauquier_County', 'Warrenton'): 0, ('Fauquier_County', 'Richmond'): 9999, ('Fauquier_County', 'Tappahannock'): 89, ('Fluvanna_County', 'Staunton'): 59, ('Fluvanna_County', 'Warrenton'): 73, ('Fluvanna_County', 'Richmond'): 64, ('Fluvanna_County', 'Tappahannock'): 104, ('Goochland_County', 'Staunton'): 81, ('Goochland_County', 'Warrenton'): 86, ('Goochland_County', 'Richmond'): 32, ('Goochland_County', 'Tappahannock'): 72, ('Greene_County', 'Staunton'): 59, ('Greene_County', 'Warrenton'): 56, ('Greene_County', 'Richmond'): 86, ('Greene_County', 'Tappahannock'): 114, ('Hanover_County', 'Staunton'): 115, ('Hanover_County', 'Warrenton'): 82, ('Hanover_County', 'Richmond'): 24, ('Hanover_County', 'Tappahannock'): 42, ('Henrico_County', 'Staunton'): 9999, ('Henrico_County', 'Warrenton'): 93, ('Henrico_County', 'Richmond'): 0, ('Henrico_County', 'Tappahannock'): 9999, ('Hopewell_County', 'Staunton'): 9999, ('Hopewell_County', 'Warrenton'): 9999, ('Hopewell_County', 'Richmond'): 22, ('Hopewell_County', 'Tappahannock'): 64, ('James_City_County', 'Staunton'): 9999, ('James_City_County', 'Warrenton'): 9999, ('James_City_County', 'Richmond'): 52, ('James_City_County', 'Tappahannock'): 72, ('King_and_Queen_County', 'Staunton'): 9999, ('King_and_Queen_County', 'Warrenton'): 109, ('King_and_Queen_County', 'Richmond'): 43, ('King_and_Queen_County', 'Tappahannock'): 19, ('King_George_County', 'Staunton'): 9999, ('King_George_County', 'Warrenton'): 58, ('King_George_County', 'Richmond'): 62, ('King_George_County', 'Tappahannock'): 36, ('King_William_County', 'Staunton'): 9999, ('King_William_County', 'Warrenton'): 98, ('King_William_County', 'Richmond'): 32, ('King_William_County', 'Tappahannock'): 25, ('Louisa_County', 'Staunton'): 9999, ('Louisa_County', 'Warrenton'): 58, ('Louisa_County', 'Richmond'): 55, ('Louisa_County', 'Tappahanno ...
# Travel Time Dictionary: {('Albemarle_County', 'Staunton'): 0.66, ('Albemarle_County', 'Warrenton'): 1.56, ('Albemarle_County', 'Richmond'): 1.22, ('Albemarle_County', 'Tappahannock'): 2.0, ('Amherst_County', 'Staunton'): 1.08, ('Amherst_County', 'Warrenton'): 9999.0, ('Amherst_County', 'Richmond'): 2.1, ('Amherst_County', 'Tappahannock'): 9999.0, ('Augusta_County', 'Staunton'): 0.0, ('Augusta_County', 'Warrenton'): 2.06, ('Augusta_County', 'Richmond'): 9999.0, ('Augusta_County', 'Tappahannock'): 9999.0, ('Buckingham_County', 'Staunton'): 1.3, ('Buckingham_County', 'Warrenton'): 2.43, ('Buckingham_County', 'Richmond'): 1.55, ('Buckingham_County', 'Tappahannock'): 9999.0, ('Caroline_County', 'Staunton'): 9999.0, ('Caroline_County', 'Warrenton'): 1.45, ('Caroline_County', 'Richmond'): 0.78, ('Caroline_County', 'Tappahannock'): 0.82, ('Charles_City_County', 'Staunton'): 9999.0, ('Charles_City_County', 'Warrenton'): 9999.0, ('Charles_City_County', 'Richmond'): 0.78, ('Charles_City_County', 'Tappahannock'): 1.52, ('Chesterfield_County', 'Staunton'): 9999.0, ('Chesterfield_County', 'Warrenton'): 2.08, ('Chesterfield_County', 'Richmond'): 0.38, ('Chesterfield_County', 'Tappahannock'): 1.32, ('City_of_Fredericksburg', 'Staunton'): 2.18, ('City_of_Fredericksburg', 'Warrenton'): 0.96, ('City_of_Fredericksburg', 'Richmond'): 1.03, ('City_of_Fredericksburg', 'Tappahannock'): 1.08, ('City_of_Richmond', 'Staunton'): 9999.0, ('City_of_Richmond', 'Warrenton'): 1.85, ('City_of_Richmond', 'Richmond'): 0.0, ('City_of_Richmond', 'Tappahannock'): 0.98, ('Culpeper_County', 'Staunton'): 1.53, ('Culpeper_County', 'Warrenton'): 0.6, ('Culpeper_County', 'Richmond'): 1.75, ('Culpeper_County', 'Tappahannock'): 1.93, ('Cumberland_County', 'Staunton'): 1.72, ('Cumberland_County', 'Warrenton'): 2.43, ('Cumberland_County', 'Richmond'): 1.13, ('Cumberland_County', 'Tappahannock'): 2.03, ('Dinwiddie_County', 'Staunton'): 9999.0, ('Dinwiddie_County', 'Warrenton'): 9999.0, ('Dinwiddie_County', 'Richmond'): 0.75, ('Dinwiddie_County', 'Tappahannock'): 1.68, ('Essex_County', 'Staunton'): 9999.0, ('Essex_County', 'Warrenton'): 1.95, ('Essex_County', 'Richmond'): 1.0, ('Essex_County', 'Tappahannock'): 0.0, ('Fauquier_County', 'Staunton'): 1.98, ('Fauquier_County', 'Warrenton'): 0.0, ('Fauquier_County', 'Richmond'): 9999.0, ('Fauquier_County', 'Tappahannock'): 1.96, ('Fluvanna_County', 'Staunton'): 1.0, ('Fluvanna_County', 'Warrenton'): 1.65, ('Fluvanna_County', 'Richmond'): 1.1, ('Fluvanna_County', 'Tappahannock'): 1.88, ('Goochland_County', 'Staunton'): 1.37, ('Goochland_County', 'Warrenton'): 1.93, ('Goochland_County', 'Richmond'): 0.63, ('Goochland_County', 'Tappahannock'): 1.42, ('Greene_County', 'Staunton'): 1.17, ('Greene_County', 'Warrenton'): 1.21, ('Greene_County', 'Richmond'): 1.57, ('Greene_County', 'Tappahannock'): 2.38, ('Hanover_County', 'Staunton'): 1.87, ('Hanover_County', 'Warrenton'): 1.58, ('Hanover_County', 'Richmond'): 0.45, ('Hanover_County', 'Tappahannock'): 0.87, ('Henrico_County', 'Staunton'): 9999.0, ('Henrico_County', 'Warrenton'): 1.75, ('Henrico_County', 'Richmond'): 0.0, ('Henrico_County', 'Tappahannock'): 9999.0, ('Hopewell_County', 'Staunton'): 9999.0, ('Hopewell_County', 'Warrenton'): 9999.0, ('Hopewell_County', 'Richmond'): 0.5, ('Hopewell_County', 'Tappahannock'): 1.25, ('James_City_County', 'Staunton'): 9999.0, ('James_City_County', 'Warrenton'): 9999.0, ('James_City_County', 'Richmond'): 0.88, ('James_City_County', 'Tappahannock'): 1.42, ('King_and_Queen_County', 'Staunton'): 9999.0, ('King_and_Queen_County', 'Warrenton'): 2.25, ('King_and_Queen_County', 'Richmond'): 0.97, ('King_and_Queen_County', 'Tappahannock'): 0.42, ('King_George_County', 'Staunton'): 9999.0, ('King_George_County', 'Warrenton'): 1.33, ('King_George_County', 'Richmond'): 1.22, ('King_George_County', 'Tappahannock'): 0.73, ('King_William_County', 'Staunton'): 9999.0, ('King_William_County', 'Warrenton'): 2.01, ('King_William_County', 'Richmond'): 0.75, ('King_Wi ...

# %%
Speed=50
# Store names and office names
stores = ['Albemarle_County', 'Amherst_County', 'Augusta_County', 'Buckingham_County',
          'Caroline_County', 'Charles_City_County', 'Chesterfield_County',
          'City_of_Fredericksburg', 'City_of_Richmond', 'Culpeper_County',
          'Cumberland_County', 'Dinwiddie_County', 'Essex_County', 'Fauquier_County',
          'Fluvanna_County', 'Goochland_County', 'Greene_County', 'Hanover_County',
          'Henrico_County', 'Hopewell_County', 'James_City_County', 'King_and_Queen_County',
          'King_George_County', 'King_William_County', 'Louisa_County', 'Madison_County',
          'Mathews_County', 'Nelson_County', 'New_Kent_County', 'Orange_County', 'Page_County',
          'Powhatan_County', 'Prince_George_County', 'Prince_William_County', 'Rappahannock_County',
          'Rockbridge_County', 'Rockingham_County', 'Shenandoah_County', 'Spotsylvania_County',
          'Stafford_County', 'Warren_County', 'Westmoreland_County', 'York_County']

offices = ['Richmond', 'Staunton', 'Warrenton', 'Tappahannock']
tasks = ['Inventory','Payroll','Hiring','Marketing','Merchandising']

# Create indices for stores and offices
store_indices = {store: i for i, store in enumerate(stores)}
office_indices = {office: j for j, office in enumerate(offices)}

travelcost = {
    (store_indices[store], office_indices[office]): mileage.get((store, office), 0) * StateMileageRate
    for store in stores
    for office in offices
}

salarycost = {
    (store_indices[store], office_indices[office]): (traveltime.get((store, office), 0) / Speed) * HourlyWage
    for store in stores
    for office in offices
}

# %%
ampl.eval('''
reset;

# Define Sets
set STORES;
set OFFICES;
set TASKS;

# Parameters
param HoursRequired {STORES, TASKS};
param Trips {STORES, TASKS};
param HoursAvailable {OFFICES, TASKS};
param Mileage {STORES, OFFICES};
param TravelTime {STORES, OFFICES};
param StateMileageRate;
param HourlyWage;

# Cost Parameters
param TravelCost {i in STORES, j in OFFICES};
param SalaryCost {i in STORES, j in OFFICES};

# Decision Variables
var x {i in STORES, j in OFFICES} binary;

# Objective: Minimize the total cost (travel + salary cost)
minimize total_cost:
    sum {i in STORES, j in OFFICES} (TravelCost[i,j] + SalaryCost[i,j]) * x[i,j];

# Constraints:
# 1. Each store must be assigned to exactly one office
s.t. store_assignment {i in STORES}:
    sum {j in OFFICES} x[i,j] = 1;

# 2. The office must have enough available hours for each task
s.t. available_hours {j in OFFICES, k in TASKS}:
    sum {i in STORES} HoursRequired[i,k] * x[i,j] <= HoursAvailable[j,k];
''')

# %%
ampl.set['STORES'] = stores;
ampl.set['OFFICES'] = offices;
ampl.set['TASKS'] = tasks

# Set the parameters for the AMPL model
# 1. HoursRequired (stores x tasks)
ampl.param['HoursRequired'] = hours

# 2. Trips (stores x offices)
ampl.param['Trips'] = trips

# 3. HoursAvailable (offices x tasks)
ampl.param['HoursAvailable'] = availability

# 4. Mileage (stores x offices)
ampl.param['Mileage'] = mileage

# 5. TravelTime (stores x offices)
ampl.param['TravelTime'] = traveltime

# 6. StateMileageRate (fixed parameter)
ampl.param['StateMileageRate'] = StateMileageRate

# 7. HourlyWage (fixed parameter)
ampl.param['HourlyWage'] = HourlyWage
# Correct TravelCost dictionary with store and office names as keys
travelcost = {
    (store, office): mileage.get((store, office), 0) * StateMileageRate
    for store in stores
    for office in offices
}

# Now pass this directly to AMPL
ampl.param['TravelCost'] = travelcost

# Salary Cost Calculation with store names and office names as keys
salarycost = {
    (store, office): (traveltime.get((store, office), 0) / Speed) * HourlyWage
    for store in stores
    for office in offices
}

# Pass SalaryCost parameter to AMPL
ampl.param['SalaryCost'] = salarycost

# %%
ampl.eval('''expand;''')
# Out:
# minimize total_cost:
# 	41.5844*x['Albemarle_County','Richmond'] +
# 	21.9882*x['Albemarle_County','Staunton'] +
# 	42.3462*x['Albemarle_County','Warrenton'] +
# 	65.39*x['Albemarle_County','Tappahannock'] +
# 	71.292*x['Amherst_County','Richmond'] +
# 	33.3216*x['Amherst_County','Staunton'] +
# 	11048.9*x['Amherst_County','Warrenton'] +
# 	11048.9*x['Amherst_County','Tappahannock'] +
# 	11048.9*x['Augusta_County','Richmond'] +
# 	71.8562*x['Augusta_County','Warrenton'] +
# 	11048.9*x['Augusta_County','Tappahannock'] +
# 	42.926*x['Buckingham_County','Richmond'] +
# 	39.286*x['Buckingham_County','Staunton'] +
# 	64.4436*x['Buckingham_County','Warrenton'] +
# 	11048.9*x['Buckingham_County','Tappahannock'] +
# 	24.9756*x['Caroline_County','Richmond'] +
# 	11048.9*x['Caroline_County','Staunton'] +
# 	37.024*x['Caroline_County','Warrenton'] +
# 	22.6564*x['Caroline_County','Tappahannock'] +
# 	22.0506*x['Charles_City_County','Richmond'] +
# 	11048.9*x['Charles_City_County','Staunton'] +
# 	11048.9*x['Charles_City_County','Warrenton'] +
# 	42.9104*x['Charles_City_County','Tappahannock'] +
# 	11.8976*x['Chesterfield_County','Richmond'] +
# 	11048.9*x['Chesterfield_County','Staunton'] +
# 	66.6016*x['Chesterfield_County','Warrenton'] +
# 	38.7114*x['Chesterfield_County','Tappahannock'] +
# 	35.0506*x['City_of_Fredericksburg','Richmond'] +
# 	66.0686*x['City_of_Fredericksburg','Staunton'] +
# 	22.7292*x['City_of_Fredericksburg','Warrenton'] +
# 	28.0566*x['City_of_Fredericksburg','Tappahannock'] +
# 	11048.9*x['City_of_Richmond','Staunton'] +
# 	50.102*x['City_of_Richmond','Warrenton'] +
# 	27.4196*x['City_of_Richmond','Tappahannock'] +
# 	52.975*x['Culpeper_County','Richmond'] +
# 	47.5956*x['Culpeper_County','Staunton'] +
# 	14.937*x['Culpeper_County','Warrenton'] +
# 	50.1436*x['Culpeper_County','Tappahannock'] +
# 	31.5926*x['Cumberland_County','Richmond'] +
# 	52.3744*x['Cumberland_County','Staunton'] +
# 	64.4436*x['Cumberland_County','Warrenton'] +
# 	60.1406*x['Cumberland_County','Tappahannock'] +
# 	23.79*x['Dinwiddie_County','Richmond'] +
# 	11048.9*x['Dinwiddie_County','Staunton'] +
# 	11048.9*x['Dinwiddie_County','Warrenton'] +
# 	50.5986*x['Dinwiddie_County','Tappahannock'] +
# 	27.43*x['Essex_County','Richmond'] +
# 	11048.9*x['Essex_County','Staunton'] +
# 	53.079*x['Essex_County','Warrenton'] +
# 	11048.9*x['Fauquier_County','Richmond'] +
# 	70.0596*x['Fauquier_County','Staunton'] +
# 	53.0842*x['Fauquier_County','Tappahannock'] +
# 	38.012*x['Fluvanna_County','Richmond'] +
# 	35.035*x['Fluvanna_County','Staunton'] +
# 	43.563*x['Fluvanna_County','Warrenton'] +
# 	61.8176*x['Fluvanna_County','Tappahannock'] +
# 	19.0476*x['Goochland_County','Richmond'] +
# 	48.0974*x['Goochland_County','Staunton'] +
# 	51.3136*x['Goochland_County','Warrenton'] +
# 	42.8584*x['Goochland_County','Tappahannock'] +
# 	51.1264*x['Greene_County','Richmond'] +
# 	35.1234*x['Greene_County','Staunton'] +
# 	33.3892*x['Greene_County','Warrenton'] +
# 	67.9276*x['Greene_County','Tappahannock'] +
# 	14.274*x['Hanover_County','Richmond'] +
# 	68.2474*x['Hanover_County','Staunton'] +
# 	48.7916*x['Hanover_County','Warrenton'] +
# 	25.0224*x['Hanover_County','Tappahannock'] +
# 	11048.9*x['Henrico_County','Staunton'] +
# 	55.315*x['Henrico_County','Warrenton'] +
# 	11048.9*x['Henrico_County','Tappahannock'] +
# 	13.13*x['Hopewell_County','Richmond'] +
# 	11048.9*x['Hopewell_County','Staunton'] +
# 	11048.9*x['Hopewell_County','Warrenton'] +
# 	38.09*x['Hopewell_County','Tappahannock'] +
# 	30.8776*x['James_City_County','Richmond'] +
# 	11048.9*x['James_City_County','Staunton'] +
# 	11048.9*x['James_City_County','Warrenton'] +
# 	42.8584*x['James_City_County','Tappahannock'] +
# 	25.6594*x['King_and_Queen_County','Richmond'] +
# 	11048.9*x['King_and_Queen_County','Staunton'] +
# 	64.935*x['King_and_Queen_County','Warrenton'] +
# 	11.3334*x['King_and_Queen_County','Tappahannock'] +
# 	36.9044*x['King_George_County','Richmond'] +
# 	11048.9*x['King_George_County','Staunton'] +
# 	34.6216*x['King_George_County','Warrenton'] +
# 	21.4396*x['King_George_County','Tappahannock'] +
# 	19.11*x['King_William_County','Richmond'] +
# 	11048.9*x['King_William_County','Staunton'] +
# 	58.3752*x['King_William_County','Warrenton'] +
# 	14.911*x['King_William_County','Tappahannock'] +
# 	32.721*x['Louisa_County','Richmond'] +
# 	11048.9*x['Louisa_County','Staunton'] +
# 	34.6164*x['Louisa_County','Warrenton'] +
# 	56.537*x['Louisa_County','Tappahannock'] +
# 	51.1472*x['Madison_County','Richmond'] +
# 	37.4582*x['Madison_County','Staunton'] +
# 	25.0484*x['Madison_County','Warrenton'] +
# 	60.8036*x['Madison_County','Tappahannock'] +
# 	43.485*x['Mathews_County','Richmond'] +
# 	11048.9*x['Mathews_County','Staunton'] +
# 	11048.9*x['Mathews_County','Warrenton'] +
# 	31.5926*x['Mathews_County','Tappahannock'] +
# 	60.762*x['Nelson_County','Richmond'] +
# 	22.6096*x['Nelson_County','Staunton'] +
# 	59.5972*x['Nelson_County','Warrenton'] +
# 	11048.9*x['Nelson_County','Tappahannock'] +
# 	17.251*x['New_Kent_County','Richmond'] +
# 	11048.9*x['New_Kent_County','Staunton'] +
# 	11048.9*x['New_Kent_County','Warrenton'] +
# 	32.1776*x['New_Kent_County','Tappahannock'] +
# 	45.162*x['Orange_County','Richmond'] +
# 	42.7752*x['Orange_County','Staunton'] +
# 	25.675*x['Orange_County','Warrenton'] +
# 	51.8466*x['Orange_County','Tappahannock'] +
# 	11048.9*x['Page_County','Richmond'] +
# 	33.8962*x['Page_County','Staunton'] +
# 	26.286*x['Page_County','Warrenton'] +
# 	11048.9*x['Page_County','Tappahannock'] +
# 	20.28*x['Powhatan_County','Richmond'] +
# 	55.2682*x['Powhatan_County','Staunton'] +
# 	58.5*x['Powhatan_County','Warrenton'] +
# 	48.854*x['Powhatan_County','Tappahannock'] +
# 	14.274*x['Prince_George_County','Richmond'] +
# 	11048.9*x['Prince_George_County','Staunton'] +
# 	11048.9*x['Prince_George_County','Warrenton'] +
# 	40.4976*x['Prince_George_County','Tappahannock'] +
# 	57.07*x['Prince_William_County','Richmond'] +
# 	11048.9*x['Prince_William_County','Staunton'] +
# 	13.1716*x['Prince_William_County','Warrenton'] +
# 	54.249*x['Prince_William_County','Tappahannock'] +
# 	70.759*x['Rappahannock_County','Richmond'] +
# 	47.0262*x['Rappahannock_County','Staunton'] +
# 	13.13*x['Rappahannock_County','Warrenton'] +
# 	66.2246*x['Rappahannock_County','Tappahannock'] +
# 	11048.9*x['Rockbridge_County','Richmond'] +
# 	20.7766*x['Rockbridge_County','Staunton'] +
# 	11048.9*x['Rockbridge_County','Warrenton'] +
# 	11048.9*x['Rockbridge_County','Tappahannock'] +
# 	11048.9*x['Rockingham_County','Richmond'] +
# 	15.4804*x['Rockingham_County','Staunton'] +
# 	56.433*x['Rockingham_County','Warrenton'] +
# 	11048.9*x['Rockingham_County','Tappahannock'] +
# 	11048.9*x['Shenandoah_County','Richmond'] +
# 	37.96*x['Shenandoah_County','Staunton'] +
# 	33.2956*x['Shenandoah_County','Warrenton'] +
# 	11048.9*x['Shenandoah_County','Tappahannock'] +
# 	35.0506*x['Spotsylvania_County','Richmond'] +
# 	63.076*x['Spotsylvania_County','Staunton'] +
# 	28.0826*x['Spotsylvania_County','Warrenton'] +
# 	32.2244*x['Spotsylvania_County','Tappahannock'] +
# 	39.7566*x['Stafford_County','Richmond'] +
# 	11048.9*x['Stafford_County','Staunton'] +
# 	25.0692*x['Stafford_County','Warrenton'] +
# 	36.9356*x['Stafford_County','Tappahannock'] +
# 	11048.9*x['Warren_County','Richmond'] +
# 	52.26*x['Warren_County','Staunton'] +
# 	19.695*x['Warren_County','Warrenton'] +
# 	11048.9*x['Warren_County','Tappahannock'] +
# 	38.7634*x['Westmoreland_County','Richmond'] +
# 	11048.9*x['Westmoreland_County','Staunton'] +
# 	50.1124*x['Westmoreland_County','Warrenton'] +
# 	11.323*x['Westmoreland_County','Tappahannock'] +
# 	38.0224*x['York_County','Richmond'] +
# 	11048.9*x['York_County','Staunton'] +
# 	11048.9*x['York_County','Warrenton'] +
# 	35.0974*x['York_County','Tappahannock'];
#
# subject to store_assignment['Albemarle_County']:
# 	x['Albemarle_County','Richmond'] + x['Albemarle_County','Staunton'] +
# 	x['Albemarle_County','Warrenton'] +
# 	x['Albemarle_County','Tappahannock'] = 1;
#
# subject to store_assignment['Amherst_County']:
# 	x['Amherst_County','Richmond'] + x['Amherst_County','Staunton'] +
# 	x['Amherst_County','Warrenton'] + x['Amherst_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Augusta_County']:
# 	x['Augusta_County','Richmond'] + x['Augusta_County','Staunton'] +
# 	x['Augusta_County','Warrenton'] + x['Augusta_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Buckingham_County']:
# 	x['Buckingham_County','Richmond'] + x['Buckingham_County','Staunton']
# 	 + x['Buckingham_County','Warrenton'] +
# 	x['Buckingham_County','Tappahannock'] = 1;
#
# subject to store_assignment['Caroline_County']:
# 	x['Caroline_County','Richmond'] + x['Caroline_County','Staunton'] +
# 	x['Caroline_County','Warrenton'] + x['Caroline_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Charles_City_County']:
# 	x['Charles_City_County','Richmond'] +
# 	x['Charles_City_County','Staunton'] +
# 	x['Charles_City_County','Warrenton'] +
# 	x['Charles_City_County','Tappahannock'] = 1;
#
# subject to store_assignment['Chesterfield_County']:
# 	x['Chesterfield_County','Richmond'] +
# 	x['Chesterfield_County','Staunton'] +
# 	x['Chesterfield_County','Warrenton'] +
# 	x['Chesterfield_County','Tappahannock'] = 1;
#
# subject to store_assignment['City_of_Fredericksburg']:
# 	x['City_of_Fredericksburg','Richmond'] +
# 	x['City_of_Fredericksburg','Staunton'] +
# 	x['City_of_Fredericksburg','Warrenton'] +
# 	x['City_of_Fredericksburg','Tappahannock'] = 1;
#
# subject to store_assignment['City_of_Richmond']:
# 	x['City_of_Richmond','Richmond'] + x['City_of_Richmond','Staunton'] +
# 	x['City_of_Richmond','Warrenton'] +
# 	x['City_of_Richmond','Tappahannock'] = 1;
#
# subject to store_assignment['Culpeper_County']:
# 	x['Culpeper_County','Richmond'] + x['Culpeper_County','Staunton'] +
# 	x['Culpeper_County','Warrenton'] + x['Culpeper_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Cumberland_County']:
# 	x['Cumberland_County','Richmond'] + x['Cumberland_County','Staunton']
# 	 + x['Cumberland_County','Warrenton'] +
# 	x['Cumberland_County','Tappahannock'] = 1;
#
# subject to store_assignment['Dinwiddie_County']:
# 	x['Dinwiddie_County','Richmond'] + x['Dinwiddie_County','Staunton'] +
# 	x['Dinwiddie_County','Warrenton'] +
# 	x['Dinwiddie_County','Tappahannock'] = 1;
#
# subject to store_assignment['Essex_County']:
# 	x['Essex_County','Richmond'] + x['Essex_County','Staunton'] +
# 	x['Essex_County','Warrenton'] + x['Essex_County','Tappahannock'] = 1;
#
# subject to store_assignment['Fauquier_County']:
# 	x['Fauquier_County','Richmond'] + x['Fauquier_County','Staunton'] +
# 	x['Fauquier_County','Warrenton'] + x['Fauquier_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Fluvanna_County']:
# 	x['Fluvanna_County','Richmond'] + x['Fluvanna_County','Staunton'] +
# 	x['Fluvanna_County','Warrenton'] + x['Fluvanna_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Goochland_County']:
# 	x['Goochland_County','Richmond'] + x['Goochland_County','Staunton'] +
# 	x['Goochland_County','Warrenton'] +
# 	x['Goochland_County','Tappahannock'] = 1;
#
# subject to store_assignment['Greene_County']:
# 	x['Greene_County','Richmond'] + x['Greene_County','Staunton'] +
# 	x['Greene_County','Warrenton'] + x['Greene_County','Tappahannock'] = 1;
#
# subject to store_assignment['Hanover_County']:
# 	x['Hanover_County','Richmond'] + x['Hanover_County','Staunton'] +
# 	x['Hanover_County','Warrenton'] + x['Hanover_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Henrico_County']:
# 	x['Henrico_County','Richmond'] + x['Henrico_County','Staunton'] +
# 	x['Henrico_County','Warrenton'] + x['Henrico_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Hopewell_County']:
# 	x['Hopewell_County','Richmond'] + x['Hopewell_County','Staunton'] +
# 	x['Hopewell_County','Warrenton'] + x['Hopewell_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['James_City_County']:
# 	x['James_City_County','Richmond'] + x['James_City_County','Staunton']
# 	 + x['James_City_County','Warrenton'] +
# 	x['James_City_County','Tappahannock'] = 1;
#
# subject to store_assignment['King_and_Queen_County']:
# 	x['King_and_Queen_County','Richmond'] +
# 	x['King_and_Queen_County','Staunton'] +
# 	x['King_and_Queen_County','Warrenton'] +
# 	x['King_and_Queen_County','Tappahannock'] = 1;
#
# subject to store_assignment['King_George_County']:
# 	x['King_George_County','Richmond'] + x['King_George_County','Staunton']
# 	 + x['King_George_County','Warrenton'] +
# 	x['King_George_County','Tappahannock'] = 1;
#
# subject to store_assignment['King_William_County']:
# 	x['King_William_County','Richmond'] +
# 	x['King_William_County','Staunton'] +
# 	x['King_William_County','Warrenton'] +
# 	x['King_William_County','Tappahannock'] = 1;
#
# subject to store_assignment['Louisa_County']:
# 	x['Louisa_County','Richmond'] + x['Louisa_County','Staunton'] +
# 	x['Louisa_County','Warrenton'] + x['Louisa_County','Tappahannock'] = 1;
#
# subject to store_assignment['Madison_County']:
# 	x['Madison_County','Richmond'] + x['Madison_County','Staunton'] +
# 	x['Madison_County','Warrenton'] + x['Madison_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Mathews_County']:
# 	x['Mathews_County','Richmond'] + x['Mathews_County','Staunton'] +
# 	x['Mathews_County','Warrenton'] + x['Mathews_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Nelson_County']:
# 	x['Nelson_County','Richmond'] + x['Nelson_County','Staunton'] +
# 	x['Nelson_County','Warrenton'] + x['Nelson_County','Tappahannock'] = 1;
#
# subject to store_assignment['New_Kent_County']:
# 	x['New_Kent_County','Richmond'] + x['New_Kent_County','Staunton'] +
# 	x['New_Kent_County','Warrenton'] + x['New_Kent_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Orange_County']:
# 	x['Orange_County','Richmond'] + x['Orange_County','Staunton'] +
# 	x['Orange_County','Warrenton'] + x['Orange_County','Tappahannock'] = 1;
#
# subject to store_assignment['Page_County']:
# 	x['Page_County','Richmond'] + x['Page_County','Staunton'] +
# 	x['Page_County','Warrenton'] + x['Page_County','Tappahannock'] = 1;
#
# subject to store_assignment['Powhatan_County']:
# 	x['Powhatan_County','Richmond'] + x['Powhatan_County','Staunton'] +
# 	x['Powhatan_County','Warrenton'] + x['Powhatan_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Prince_George_County']:
# 	x['Prince_George_County','Richmond'] +
# 	x['Prince_George_County','Staunton'] +
# 	x['Prince_George_County','Warrenton'] +
# 	x['Prince_George_County','Tappahannock'] = 1;
#
# subject to store_assignment['Prince_William_County']:
# 	x['Prince_William_County','Richmond'] +
# 	x['Prince_William_County','Staunton'] +
# 	x['Prince_William_County','Warrenton'] +
# 	x['Prince_William_County','Tappahannock'] = 1;
#
# subject to store_assignment['Rappahannock_County']:
# 	x['Rappahannock_County','Richmond'] +
# 	x['Rappahannock_County','Staunton'] +
# 	x['Rappahannock_County','Warrenton'] +
# 	x['Rappahannock_County','Tappahannock'] = 1;
#
# subject to store_assignment['Rockbridge_County']:
# 	x['Rockbridge_County','Richmond'] + x['Rockbridge_County','Staunton']
# 	 + x['Rockbridge_County','Warrenton'] +
# 	x['Rockbridge_County','Tappahannock'] = 1;
#
# subject to store_assignment['Rockingham_County']:
# 	x['Rockingham_County','Richmond'] + x['Rockingham_County','Staunton']
# 	 + x['Rockingham_County','Warrenton'] +
# 	x['Rockingham_County','Tappahannock'] = 1;
#
# subject to store_assignment['Shenandoah_County']:
# 	x['Shenandoah_County','Richmond'] + x['Shenandoah_County','Staunton']
# 	 + x['Shenandoah_County','Warrenton'] +
# 	x['Shenandoah_County','Tappahannock'] = 1;
#
# subject to store_assignment['Spotsylvania_County']:
# 	x['Spotsylvania_County','Richmond'] +
# 	x['Spotsylvania_County','Staunton'] +
# 	x['Spotsylvania_County','Warrenton'] +
# 	x['Spotsylvania_County','Tappahannock'] = 1;
#
# subject to store_assignment['Stafford_County']:
# 	x['Stafford_County','Richmond'] + x['Stafford_County','Staunton'] +
# 	x['Stafford_County','Warrenton'] + x['Stafford_County','Tappahannock']
# 	 = 1;
#
# subject to store_assignment['Warren_County']:
# 	x['Warren_County','Richmond'] + x['Warren_County','Staunton'] +
# 	x['Warren_County','Warrenton'] + x['Warren_County','Tappahannock'] = 1;
#
# subject to store_assignment['Westmoreland_County']:
# 	x['Westmoreland_County','Richmond'] +
# 	x['Westmoreland_County','Staunton'] +
# 	x['Westmoreland_County','Warrenton'] +
# 	x['Westmoreland_County','Tappahannock'] = 1;
#
# subject to store_assignment['York_County']:
# 	x['York_County','Richmond'] + x['York_County','Staunton'] +
# 	x['York_County','Warrenton'] + x['York_County','Tappahannock'] = 1;
#
# subject to available_hours['Richmond','Inventory']:
# 	460*x['Albemarle_County','Richmond'] + 2*x['Amherst_County','Richmond']
# 	 + 341*x['Augusta_County','Richmond'] +
# 	46*x['Buckingham_County','Richmond'] +
# 	13*x['Caroline_County','Richmond'] +
# 	90*x['Charles_City_County','Richmond'] +
# 	655*x['Chesterfield_County','Richmond'] +
# 	123*x['City_of_Fredericksburg','Richmond'] +
# 	468*x['City_of_Richmond','Richmond'] +
# 	12*x['Culpeper_County','Richmond'] +
# 	21*x['Cumberland_County','Richmond'] +
# 	300*x['Dinwiddie_County','Richmond'] + 63*x['Essex_County','Richmond']
# 	 + 55*x['Fauquier_County','Richmond'] +
# 	4*x['Fluvanna_County','Richmond'] + 12*x['Goochland_County','Richmond']
# 	 + 36*x['Greene_County','Richmond'] + 96*x['Henrico_County','Richmond']
# 	 + 7*x['Hopewell_County','Richmond'] +
# 	350*x['James_City_County','Richmond'] +
# 	25*x['King_and_Queen_County','Richmond'] +
# 	16*x['King_George_County','Richmond'] +
# 	30*x['King_William_County','Richmond'] +
# 	270*x['Louisa_County','Richmond'] + 21*x['Madison_County','Richmond']
# 	 + 220*x['Mathews_County','Richmond'] +
# 	14*x['Nelson_County','Richmond'] + 15*x['New_Kent_County','Richmond']
# 	 + 27*x['Orange_County','Richmond'] + 100*x['Page_County','Richmond']
# 	 + 16*x['Powhatan_County','Richmond'] +
# 	8*x['Prince_George_County','Richmond'] +
# 	332*x['Prince_William_County','Richmond'] +
# 	101*x['Rockbridge_County','Richmond'] +
# 	600*x['Rockingham_County','Richmond'] +
# 	100*x['Shenandoah_County','Richmond'] +
# 	8*x['Spotsylvania_County','Richmond'] +
# 	16*x['Stafford_County','Richmond'] + 2*x['Warren_County','Richmond'] +
# 	105*x['Westmoreland_County','Richmond'] +
# 	30*x['York_County','Richmond'] <= 5000;
#
# subject to available_hours['Richmond','Payroll']:
# 	771*x['Albemarle_County','Richmond'] +
# 	28*x['Amherst_County','Richmond'] + 737*x['Augusta_County','Richmond']
# 	 + 40*x['Buckingham_County','Richmond'] +
# 	136*x['Caroline_County','Richmond'] +
# 	26*x['Charles_City_County','Richmond'] +
# 	343*x['Chesterfield_County','Richmond'] +
# 	64*x['City_of_Fredericksburg','Richmond'] +
# 	264*x['City_of_Richmond','Richmond'] +
# 	96*x['Culpeper_County','Richmond'] +
# 	33*x['Cumberland_County','Richmond'] +
# 	188*x['Dinwiddie_County','Richmond'] + 30*x['Essex_County','Richmond']
# 	 + 228*x['Fauquier_County','Richmond'] +
# 	96*x['Fluvanna_County','Richmond'] +
# 	97*x['Goochland_County','Richmond'] + 88*x['Greene_County','Richmond']
# 	 + 184*x['Hanover_County','Richmond'] +
# 	227*x['Henrico_County','Richmond'] + 36*x['Hopewell_County','Richmond']
# 	 + 127*x['James_City_County','Richmond'] +
# 	14*x['King_and_Queen_County','Richmond'] +
# 	56*x['King_George_County','Richmond'] +
# 	70*x['King_William_County','Richmond'] +
# 	114*x['Louisa_County','Richmond'] + 32*x['Madison_County','Richmond']
# 	 + 21*x['Mathews_County','Richmond'] + 71*x['Nelson_County','Richmond']
# 	 + 52*x['New_Kent_County','Richmond'] +
# 	136*x['Orange_County','Richmond'] + 170*x['Page_County','Richmond'] +
# 	148*x['Powhatan_County','Richmond'] +
# 	24*x['Prince_George_County','Richmond'] +
# 	385*x['Prince_William_County','Richmond'] +
# 	8*x['Rappahannock_County','Richmond'] +
# 	470*x['Rockbridge_County','Richmond'] +
# 	761*x['Rockingham_County','Richmond'] +
# 	97*x['Shenandoah_County','Richmond'] +
# 	192*x['Spotsylvania_County','Richmond'] +
# 	200*x['Stafford_County','Richmond'] + 121*x['Warren_County','Richmond']
# 	 + 17*x['Westmoreland_County','Richmond'] +
# 	91*x['York_County','Richmond'] <= 3025;
#
# subject to available_hours['Richmond','Hiring']:
# 	2806*x['Augusta_County','Richmond'] +
# 	408*x['Buckingham_County','Richmond'] +
# 	170*x['Caroline_County','Richmond'] +
# 	17*x['Chesterfield_County','Richmond'] +
# 	60*x['City_of_Fredericksburg','Richmond'] +
# 	200*x['Culpeper_County','Richmond'] +
# 	480*x['Dinwiddie_County','Richmond'] + 680*x['Essex_County','Richmond']
# 	 + 280*x['Fauquier_County','Richmond'] +
# 	150*x['Greene_County','Richmond'] + 150*x['Hanover_County','Richmond']
# 	 + 60*x['James_City_County','Richmond'] +
# 	340*x['King_and_Queen_County','Richmond'] +
# 	150*x['King_George_County','Richmond'] +
# 	60*x['King_William_County','Richmond'] +
# 	150*x['Madison_County','Richmond'] + 60*x['New_Kent_County','Richmond']
# 	 + 150*x['Orange_County','Richmond'] + 176*x['Page_County','Richmond']
# 	 + 60*x['Powhatan_County','Richmond'] +
# 	60*x['Prince_George_County','Richmond'] +
# 	315*x['Prince_William_County','Richmond'] +
# 	150*x['Rappahannock_County','Richmond'] +
# 	450*x['Rockbridge_County','Richmond'] +
# 	3175*x['Rockingham_County','Richmond'] +
# 	120*x['Shenandoah_County','Richmond'] +
# 	150*x['Spotsylvania_County','Richmond'] +
# 	100*x['Stafford_County','Richmond'] +
# 	120*x['Westmoreland_County','Richmond'] <= 1225;
#
# subject to available_hours['Richmond','Marketing']:
# 	96*x['Albemarle_County','Richmond'] + 8*x['Amherst_County','Richmond']
# 	 + 260*x['Augusta_County','Richmond'] +
# 	84*x['Buckingham_County','Richmond'] +
# 	10*x['Caroline_County','Richmond'] +
# 	40*x['Charles_City_County','Richmond'] +
# 	144*x['Chesterfield_County','Richmond'] +
# 	14*x['Cumberland_County','Richmond'] +
# 	160*x['Dinwiddie_County','Richmond'] + 200*x['Essex_County','Richmond']
# 	 + 320*x['Fauquier_County','Richmond'] +
# 	8*x['Fluvanna_County','Richmond'] + 70*x['Goochland_County','Richmond']
# 	 + 200*x['Hanover_County','Richmond'] +
# 	84*x['Henrico_County','Richmond'] +
# 	40*x['King_and_Queen_County','Richmond'] +
# 	40*x['King_William_County','Richmond'] +
# 	8*x['Louisa_County','Richmond'] + 10*x['Mathews_County','Richmond'] +
# 	8*x['Nelson_County','Richmond'] + 200*x['New_Kent_County','Richmond']
# 	 + 8*x['Page_County','Richmond'] + 22*x['Powhatan_County','Richmond']
# 	 + 52*x['Prince_George_County','Richmond'] +
# 	256*x['Prince_William_County','Richmond'] +
# 	226*x['Rockbridge_County','Richmond'] +
# 	288*x['Rockingham_County','Richmond'] +
# 	4*x['Shenandoah_County','Richmond'] + 2*x['Warren_County','Richmond']
# 	 + 10*x['Westmoreland_County','Richmond'] +
# 	10*x['York_County','Richmond'] <= 1750;
#
# subject to available_hours['Richmond','Merchandising']:
# 	90*x['Albemarle_County','Richmond'] + 65*x['Augusta_County','Richmond']
# 	 + 59*x['Buckingham_County','Richmond'] +
# 	55*x['Caroline_County','Richmond'] +
# 	15*x['Charles_City_County','Richmond'] +
# 	8*x['Chesterfield_County','Richmond'] +
# 	70*x['City_of_Fredericksburg','Richmond'] +
# 	2*x['City_of_Richmond','Richmond'] +
# 	120*x['Culpeper_County','Richmond'] +
# 	50*x['Dinwiddie_County','Richmond'] + 80*x['Essex_County','Richmond']
# 	 + 40*x['Fauquier_County','Richmond'] +
# 	5*x['Goochland_County','Richmond'] + 40*x['Greene_County','Richmond']
# 	 + 120*x['Hanover_County','Richmond'] +
# 	78*x['Henrico_County','Richmond'] + 4*x['Hopewell_County','Richmond']
# 	 + 140*x['James_City_County','Richmond'] +
# 	60*x['King_and_Queen_County','Richmond'] +
# 	70*x['King_George_County','Richmond'] +
# 	60*x['King_William_County','Richmond'] +
# 	25*x['Louisa_County','Richmond'] + 40*x['Madison_County','Richmond'] +
# 	60*x['Mathews_County','Richmond'] + 60*x['New_Kent_County','Richmond']
# 	 + 25*x['Orange_County','Richmond'] + 40*x['Page_County','Richmond'] +
# 	288*x['Prince_William_County','Richmond'] +
# 	130*x['Rappahannock_County','Richmond'] +
# 	28*x['Rockbridge_County','Richmond'] +
# 	65*x['Rockingham_County','Richmond'] +
# 	25*x['Shenandoah_County','Richmond'] +
# 	90*x['Spotsylvania_County','Richmond'] +
# 	110*x['Stafford_County','Richmond'] + 5*x['Warren_County','Richmond']
# 	 + 40*x['Westmoreland_County','Richmond'] +
# 	50*x['York_County','Richmond'] <= 3675;
#
# subject to available_hours['Staunton','Inventory']:
# 	460*x['Albemarle_County','Staunton'] + 2*x['Amherst_County','Staunton']
# 	 + 341*x['Augusta_County','Staunton'] +
# 	46*x['Buckingham_County','Staunton'] +
# 	13*x['Caroline_County','Staunton'] +
# 	90*x['Charles_City_County','Staunton'] +
# 	655*x['Chesterfield_County','Staunton'] +
# 	123*x['City_of_Fredericksburg','Staunton'] +
# 	468*x['City_of_Richmond','Staunton'] +
# 	12*x['Culpeper_County','Staunton'] +
# 	21*x['Cumberland_County','Staunton'] +
# 	300*x['Dinwiddie_County','Staunton'] + 63*x['Essex_County','Staunton']
# 	 + 55*x['Fauquier_County','Staunton'] +
# 	4*x['Fluvanna_County','Staunton'] + 12*x['Goochland_County','Staunton']
# 	 + 36*x['Greene_County','Staunton'] + 96*x['Henrico_County','Staunton']
# 	 + 7*x['Hopewell_County','Staunton'] +
# 	350*x['James_City_County','Staunton'] +
# 	25*x['King_and_Queen_County','Staunton'] +
# 	16*x['King_George_County','Staunton'] +
# 	30*x['King_William_County','Staunton'] +
# 	270*x['Louisa_County','Staunton'] + 21*x['Madison_County','Staunton']
# 	 + 220*x['Mathews_County','Staunton'] +
# 	14*x['Nelson_County','Staunton'] + 15*x['New_Kent_County','Staunton']
# 	 + 27*x['Orange_County','Staunton'] + 100*x['Page_County','Staunton']
# 	 + 16*x['Powhatan_County','Staunton'] +
# 	8*x['Prince_George_County','Staunton'] +
# 	332*x['Prince_William_County','Staunton'] +
# 	101*x['Rockbridge_County','Staunton'] +
# 	600*x['Rockingham_County','Staunton'] +
# 	100*x['Shenandoah_County','Staunton'] +
# 	8*x['Spotsylvania_County','Staunton'] +
# 	16*x['Stafford_County','Staunton'] + 2*x['Warren_County','Staunton'] +
# 	105*x['Westmoreland_County','Staunton'] +
# 	30*x['York_County','Staunton'] <= 3550;
#
# subject to available_hours['Staunton','Payroll']:
# 	771*x['Albemarle_County','Staunton'] +
# 	28*x['Amherst_County','Staunton'] + 737*x['Augusta_County','Staunton']
# 	 + 40*x['Buckingham_County','Staunton'] +
# 	136*x['Caroline_County','Staunton'] +
# 	26*x['Charles_City_County','Staunton'] +
# 	343*x['Chesterfield_County','Staunton'] +
# 	64*x['City_of_Fredericksburg','Staunton'] +
# 	264*x['City_of_Richmond','Staunton'] +
# 	96*x['Culpeper_County','Staunton'] +
# 	33*x['Cumberland_County','Staunton'] +
# 	188*x['Dinwiddie_County','Staunton'] + 30*x['Essex_County','Staunton']
# 	 + 228*x['Fauquier_County','Staunton'] +
# 	96*x['Fluvanna_County','Staunton'] +
# 	97*x['Goochland_County','Staunton'] + 88*x['Greene_County','Staunton']
# 	 + 184*x['Hanover_County','Staunton'] +
# 	227*x['Henrico_County','Staunton'] + 36*x['Hopewell_County','Staunton']
# 	 + 127*x['James_City_County','Staunton'] +
# 	14*x['King_and_Queen_County','Staunton'] +
# 	56*x['King_George_County','Staunton'] +
# 	70*x['King_William_County','Staunton'] +
# 	114*x['Louisa_County','Staunton'] + 32*x['Madison_County','Staunton']
# 	 + 21*x['Mathews_County','Staunton'] + 71*x['Nelson_County','Staunton']
# 	 + 52*x['New_Kent_County','Staunton'] +
# 	136*x['Orange_County','Staunton'] + 170*x['Page_County','Staunton'] +
# 	148*x['Powhatan_County','Staunton'] +
# 	24*x['Prince_George_County','Staunton'] +
# 	385*x['Prince_William_County','Staunton'] +
# 	8*x['Rappahannock_County','Staunton'] +
# 	470*x['Rockbridge_County','Staunton'] +
# 	761*x['Rockingham_County','Staunton'] +
# 	97*x['Shenandoah_County','Staunton'] +
# 	192*x['Spotsylvania_County','Staunton'] +
# 	200*x['Stafford_County','Staunton'] + 121*x['Warren_County','Staunton']
# 	 + 17*x['Westmoreland_County','Staunton'] +
# 	91*x['York_County','Staunton'] <= 3450;
#
# subject to available_hours['Staunton','Hiring']:
# 	2806*x['Augusta_County','Staunton'] +
# 	408*x['Buckingham_County','Staunton'] +
# 	170*x['Caroline_County','Staunton'] +
# 	17*x['Chesterfield_County','Staunton'] +
# 	60*x['City_of_Fredericksburg','Staunton'] +
# 	200*x['Culpeper_County','Staunton'] +
# 	480*x['Dinwiddie_County','Staunton'] + 680*x['Essex_County','Staunton']
# 	 + 280*x['Fauquier_County','Staunton'] +
# 	150*x['Greene_County','Staunton'] + 150*x['Hanover_County','Staunton']
# 	 + 60*x['James_City_County','Staunton'] +
# 	340*x['King_and_Queen_County','Staunton'] +
# 	150*x['King_George_County','Staunton'] +
# 	60*x['King_William_County','Staunton'] +
# 	150*x['Madison_County','Staunton'] + 60*x['New_Kent_County','Staunton']
# 	 + 150*x['Orange_County','Staunton'] + 176*x['Page_County','Staunton']
# 	 + 60*x['Powhatan_County','Staunton'] +
# 	60*x['Prince_George_County','Staunton'] +
# 	315*x['Prince_William_County','Staunton'] +
# 	150*x['Rappahannock_County','Staunton'] +
# 	450*x['Rockbridge_County','Staunton'] +
# 	3175*x['Rockingham_County','Staunton'] +
# 	120*x['Shenandoah_County','Staunton'] +
# 	150*x['Spotsylvania_County','Staunton'] +
# 	100*x['Stafford_County','Staunton'] +
# 	120*x['Westmoreland_County','Staunton'] <= 9100;
#
# subject to available_hours['Staunton','Marketing']:
# 	96*x['Albemarle_County','Staunton'] + 8*x['Amherst_County','Staunton']
# 	 + 260*x['Augusta_County','Staunton'] +
# 	84*x['Buckingham_County','Staunton'] +
# 	10*x['Caroline_County','Staunton'] +
# 	40*x['Charles_City_County','Staunton'] +
# 	144*x['Chesterfield_County','Staunton'] +
# 	14*x['Cumberland_County','Staunton'] +
# 	160*x['Dinwiddie_County','Staunton'] + 200*x['Essex_County','Staunton']
# 	 + 320*x['Fauquier_County','Staunton'] +
# 	8*x['Fluvanna_County','Staunton'] + 70*x['Goochland_County','Staunton']
# 	 + 200*x['Hanover_County','Staunton'] +
# 	84*x['Henrico_County','Staunton'] +
# 	40*x['King_and_Queen_County','Staunton'] +
# 	40*x['King_William_County','Staunton'] +
# 	8*x['Louisa_County','Staunton'] + 10*x['Mathews_County','Staunton'] +
# 	8*x['Nelson_County','Staunton'] + 200*x['New_Kent_County','Staunton']
# 	 + 8*x['Page_County','Staunton'] + 22*x['Powhatan_County','Staunton']
# 	 + 52*x['Prince_George_County','Staunton'] +
# 	256*x['Prince_William_County','Staunton'] +
# 	226*x['Rockbridge_County','Staunton'] +
# 	288*x['Rockingham_County','Staunton'] +
# 	4*x['Shenandoah_County','Staunton'] + 2*x['Warren_County','Staunton']
# 	 + 10*x['Westmoreland_County','Staunton'] +
# 	10*x['York_County','Staunton'] <= 1700;
#
# subject to available_hours['Staunton','Merchandising']:
# 	90*x['Albemarle_County','Staunton'] + 65*x['Augusta_County','Staunton']
# 	 + 59*x['Buckingham_County','Staunton'] +
# 	55*x['Caroline_County','Staunton'] +
# 	15*x['Charles_City_County','Staunton'] +
# 	8*x['Chesterfield_County','Staunton'] +
# 	70*x['City_of_Fredericksburg','Staunton'] +
# 	2*x['City_of_Richmond','Staunton'] +
# 	120*x['Culpeper_County','Staunton'] +
# 	50*x['Dinwiddie_County','Staunton'] + 80*x['Essex_County','Staunton']
# 	 + 40*x['Fauquier_County','Staunton'] +
# 	5*x['Goochland_County','Staunton'] + 40*x['Greene_County','Staunton']
# 	 + 120*x['Hanover_County','Staunton'] +
# 	78*x['Henrico_County','Staunton'] + 4*x['Hopewell_County','Staunton']
# 	 + 140*x['James_City_County','Staunton'] +
# 	60*x['King_and_Queen_County','Staunton'] +
# 	70*x['King_George_County','Staunton'] +
# 	60*x['King_William_County','Staunton'] +
# 	25*x['Louisa_County','Staunton'] + 40*x['Madison_County','Staunton'] +
# 	60*x['Mathews_County','Staunton'] + 60*x['New_Kent_County','Staunton']
# 	 + 25*x['Orange_County','Staunton'] + 40*x['Page_County','Staunton'] +
# 	288*x['Prince_William_County','Staunton'] +
# 	130*x['Rappahannock_County','Staunton'] +
# 	28*x['Rockbridge_County','Staunton'] +
# 	65*x['Rockingham_County','Staunton'] +
# 	25*x['Shenandoah_County','Staunton'] +
# 	90*x['Spotsylvania_County','Staunton'] +
# 	110*x['Stafford_County','Staunton'] + 5*x['Warren_County','Staunton']
# 	 + 40*x['Westmoreland_County','Staunton'] +
# 	50*x['York_County','Staunton'] <= 1850;
#
# subject to available_hours['Warrenton','Inventory']:
# 	460*x['Albemarle_County','Warrenton'] +
# 	2*x['Amherst_County','Warrenton'] + 341*x['Augusta_County','Warrenton']
# 	 + 46*x['Buckingham_County','Warrenton'] +
# 	13*x['Caroline_County','Warrenton'] +
# 	90*x['Charles_City_County','Warrenton'] +
# 	655*x['Chesterfield_County','Warrenton'] +
# 	123*x['City_of_Fredericksburg','Warrenton'] +
# 	468*x['City_of_Richmond','Warrenton'] +
# 	12*x['Culpeper_County','Warrenton'] +
# 	21*x['Cumberland_County','Warrenton'] +
# 	300*x['Dinwiddie_County','Warrenton'] +
# 	63*x['Essex_County','Warrenton'] + 55*x['Fauquier_County','Warrenton']
# 	 + 4*x['Fluvanna_County','Warrenton'] +
# 	12*x['Goochland_County','Warrenton'] +
# 	36*x['Greene_County','Warrenton'] + 96*x['Henrico_County','Warrenton']
# 	 + 7*x['Hopewell_County','Warrenton'] +
# 	350*x['James_City_County','Warrenton'] +
# 	25*x['King_and_Queen_County','Warrenton'] +
# 	16*x['King_George_County','Warrenton'] +
# 	30*x['King_William_County','Warrenton'] +
# 	270*x['Louisa_County','Warrenton'] + 21*x['Madison_County','Warrenton']
# 	 + 220*x['Mathews_County','Warrenton'] +
# 	14*x['Nelson_County','Warrenton'] + 15*x['New_Kent_County','Warrenton']
# 	 + 27*x['Orange_County','Warrenton'] + 100*x['Page_County','Warrenton']
# 	 + 16*x['Powhatan_County','Warrenton'] +
# 	8*x['Prince_George_County','Warrenton'] +
# 	332*x['Prince_William_County','Warrenton'] +
# 	101*x['Rockbridge_County','Warrenton'] +
# 	600*x['Rockingham_County','Warrenton'] +
# 	100*x['Shenandoah_County','Warrenton'] +
# 	8*x['Spotsylvania_County','Warrenton'] +
# 	16*x['Stafford_County','Warrenton'] + 2*x['Warren_County','Warrenton']
# 	 + 105*x['Westmoreland_County','Warrenton'] +
# 	30*x['York_County','Warrenton'] <= 825;
#
# subject to available_hours['Warrenton','Payroll']:
# 	771*x['Albemarle_County','Warrenton'] +
# 	28*x['Amherst_County','Warrenton'] +
# 	737*x['Augusta_County','Warrenton'] +
# 	40*x['Buckingham_County','Warrenton'] +
# 	136*x['Caroline_County','Warrenton'] +
# 	26*x['Charles_City_County','Warrenton'] +
# 	343*x['Chesterfield_County','Warrenton'] +
# 	64*x['City_of_Fredericksburg','Warrenton'] +
# 	264*x['City_of_Richmond','Warrenton'] +
# 	96*x['Culpeper_County','Warrenton'] +
# 	33*x['Cumberland_County','Warrenton'] +
# 	188*x['Dinwiddie_County','Warrenton'] +
# 	30*x['Essex_County','Warrenton'] + 228*x['Fauquier_County','Warrenton']
# 	 + 96*x['Fluvanna_County','Warrenton'] +
# 	97*x['Goochland_County','Warrenton'] +
# 	88*x['Greene_County','Warrenton'] + 184*x['Hanover_County','Warrenton']
# 	 + 227*x['Henrico_County','Warrenton'] +
# 	36*x['Hopewell_County','Warrenton'] +
# 	127*x['James_City_County','Warrenton'] +
# 	14*x['King_and_Queen_County','Warrenton'] +
# 	56*x['King_George_County','Warrenton'] +
# 	70*x['King_William_County','Warrenton'] +
# 	114*x['Louisa_County','Warrenton'] + 32*x['Madison_County','Warrenton']
# 	 + 21*x['Mathews_County','Warrenton'] +
# 	71*x['Nelson_County','Warrenton'] + 52*x['New_Kent_County','Warrenton']
# 	 + 136*x['Orange_County','Warrenton'] +
# 	170*x['Page_County','Warrenton'] + 148*x['Powhatan_County','Warrenton']
# 	 + 24*x['Prince_George_County','Warrenton'] +
# 	385*x['Prince_William_County','Warrenton'] +
# 	8*x['Rappahannock_County','Warrenton'] +
# 	470*x['Rockbridge_County','Warrenton'] +
# 	761*x['Rockingham_County','Warrenton'] +
# 	97*x['Shenandoah_County','Warrenton'] +
# 	192*x['Spotsylvania_County','Warrenton'] +
# 	200*x['Stafford_County','Warrenton'] +
# 	121*x['Warren_County','Warrenton'] +
# 	17*x['Westmoreland_County','Warrenton'] +
# 	91*x['York_County','Warrenton'] <= 2500;
#
# subject to available_hours['Warrenton','Hiring']:
# 	2806*x['Augusta_County','Warrenton'] +
# 	408*x['Buckingham_County','Warrenton'] +
# 	170*x['Caroline_County','Warrenton'] +
# 	17*x['Chesterfield_County','Warrenton'] +
# 	60*x['City_of_Fredericksburg','Warrenton'] +
# 	200*x['Culpeper_County','Warrenton'] +
# 	480*x['Dinwiddie_County','Warrenton'] +
# 	680*x['Essex_County','Warrenton'] +
# 	280*x['Fauquier_County','Warrenton'] +
# 	150*x['Greene_County','Warrenton'] +
# 	150*x['Hanover_County','Warrenton'] +
# 	60*x['James_City_County','Warrenton'] +
# 	340*x['King_and_Queen_County','Warrenton'] +
# 	150*x['King_George_County','Warrenton'] +
# 	60*x['King_William_County','Warrenton'] +
# 	150*x['Madison_County','Warrenton'] +
# 	60*x['New_Kent_County','Warrenton'] +
# 	150*x['Orange_County','Warrenton'] + 176*x['Page_County','Warrenton']
# 	 + 60*x['Powhatan_County','Warrenton'] +
# 	60*x['Prince_George_County','Warrenton'] +
# 	315*x['Prince_William_County','Warrenton'] +
# 	150*x['Rappahannock_County','Warrenton'] +
# 	450*x['Rockbridge_County','Warrenton'] +
# 	3175*x['Rockingham_County','Warrenton'] +
# 	120*x['Shenandoah_County','Warrenton'] +
# 	150*x['Spotsylvania_County','Warrenton'] +
# 	100*x['Stafford_County','Warrenton'] +
# 	120*x['Westmoreland_County','Warrenton'] <= 3375;
#
# subject to available_hours['Warrenton','Marketing']:
# 	96*x['Albemarle_County','Warrenton'] +
# 	8*x['Amherst_County','Warrenton'] + 260*x['Augusta_County','Warrenton']
# 	 + 84*x['Buckingham_County','Warrenton'] +
# 	10*x['Caroline_County','Warrenton'] +
# 	40*x['Charles_City_County','Warrenton'] +
# 	144*x['Chesterfield_County','Warrenton'] +
# 	14*x['Cumberland_County','Warrenton'] +
# 	160*x['Dinwiddie_County','Warrenton'] +
# 	200*x['Essex_County','Warrenton'] +
# 	320*x['Fauquier_County','Warrenton'] +
# 	8*x['Fluvanna_County','Warrenton'] +
# 	70*x['Goochland_County','Warrenton'] +
# 	200*x['Hanover_County','Warrenton'] +
# 	84*x['Henrico_County','Warrenton'] +
# 	40*x['King_and_Queen_County','Warrenton'] +
# 	40*x['King_William_County','Warrenton'] +
# 	8*x['Louisa_County','Warrenton'] + 10*x['Mathews_County','Warrenton']
# 	 + 8*x['Nelson_County','Warrenton'] +
# 	200*x['New_Kent_County','Warrenton'] + 8*x['Page_County','Warrenton']
# 	 + 22*x['Powhatan_County','Warrenton'] +
# 	52*x['Prince_George_County','Warrenton'] +
# 	256*x['Prince_William_County','Warrenton'] +
# 	226*x['Rockbridge_County','Warrenton'] +
# 	288*x['Rockingham_County','Warrenton'] +
# 	4*x['Shenandoah_County','Warrenton'] + 2*x['Warren_County','Warrenton']
# 	 + 10*x['Westmoreland_County','Warrenton'] +
# 	10*x['York_County','Warrenton'] <= 1325;
#
# subject to available_hours['Warrenton','Merchandising']:
# 	90*x['Albemarle_County','Warrenton'] +
# 	65*x['Augusta_County','Warrenton'] +
# 	59*x['Buckingham_County','Warrenton'] +
# 	55*x['Caroline_County','Warrenton'] +
# 	15*x['Charles_City_County','Warrenton'] +
# 	8*x['Chesterfield_County','Warrenton'] +
# 	70*x['City_of_Fredericksburg','Warrenton'] +
# 	2*x['City_of_Richmond','Warrenton'] +
# 	120*x['Culpeper_County','Warrenton'] +
# 	50*x['Dinwiddie_County','Warrenton'] + 80*x['Essex_County','Warrenton']
# 	 + 40*x['Fauquier_County','Warrenton'] +
# 	5*x['Goochland_County','Warrenton'] + 40*x['Greene_County','Warrenton']
# 	 + 120*x['Hanover_County','Warrenton'] +
# 	78*x['Henrico_County','Warrenton'] + 4*x['Hopewell_County','Warrenton']
# 	 + 140*x['James_City_County','Warrenton'] +
# 	60*x['King_and_Queen_County','Warrenton'] +
# 	70*x['King_George_County','Warrenton'] +
# 	60*x['King_William_County','Warrenton'] +
# 	25*x['Louisa_County','Warrenton'] + 40*x['Madison_County','Warrenton']
# 	 + 60*x['Mathews_County','Warrenton'] +
# 	60*x['New_Kent_County','Warrenton'] + 25*x['Orange_County','Warrenton']
# 	 + 40*x['Page_County','Warrenton'] +
# 	288*x['Prince_William_County','Warrenton'] +
# 	130*x['Rappahannock_County','Warrenton'] +
# 	28*x['Rockbridge_County','Warrenton'] +
# 	65*x['Rockingham_County','Warrenton'] +
# 	25*x['Shenandoah_County','Warrenton'] +
# 	90*x['Spotsylvania_County','Warrenton'] +
# 	110*x['Stafford_County','Warrenton'] + 5*x['Warren_County','Warrenton']
# 	 + 40*x['Westmoreland_County','Warrenton'] +
# 	50*x['York_County','Warrenton'] <= 850;
#
# subject to available_hours['Tappahannock','Inventory']:
# 	460*x['Albemarle_County','Tappahannock'] +
# 	2*x['Amherst_County','Tappahannock'] +
# 	341*x['Augusta_County','Tappahannock'] +
# 	46*x['Buckingham_County','Tappahannock'] +
# 	13*x['Caroline_County','Tappahannock'] +
# 	90*x['Charles_City_County','Tappahannock'] +
# 	655*x['Chesterfield_County','Tappahannock'] +
# 	123*x['City_of_Fredericksburg','Tappahannock'] +
# 	468*x['City_of_Richmond','Tappahannock'] +
# 	12*x['Culpeper_County','Tappahannock'] +
# 	21*x['Cumberland_County','Tappahannock'] +
# 	300*x['Dinwiddie_County','Tappahannock'] +
# 	63*x['Essex_County','Tappahannock'] +
# 	55*x['Fauquier_County','Tappahannock'] +
# 	4*x['Fluvanna_County','Tappahannock'] +
# 	12*x['Goochland_County','Tappahannock'] +
# 	36*x['Greene_County','Tappahannock'] +
# 	96*x['Henrico_County','Tappahannock'] +
# 	7*x['Hopewell_County','Tappahannock'] +
# 	350*x['James_City_County','Tappahannock'] +
# 	25*x['King_and_Queen_County','Tappahannock'] +
# 	16*x['King_George_County','Tappahannock'] +
# 	30*x['King_William_County','Tappahannock'] +
# 	270*x['Louisa_County','Tappahannock'] +
# 	21*x['Madison_County','Tappahannock'] +
# 	220*x['Mathews_County','Tappahannock'] +
# 	14*x['Nelson_County','Tappahannock'] +
# 	15*x['New_Kent_County','Tappahannock'] +
# 	27*x['Orange_County','Tappahannock'] +
# 	100*x['Page_County','Tappahannock'] +
# 	16*x['Powhatan_County','Tappahannock'] +
# 	8*x['Prince_George_County','Tappahannock'] +
# 	332*x['Prince_William_County','Tappahannock'] +
# 	101*x['Rockbridge_County','Tappahannock'] +
# 	600*x['Rockingham_County','Tappahannock'] +
# 	100*x['Shenandoah_County','Tappahannock'] +
# 	8*x['Spotsylvania_County','Tappahannock'] +
# 	16*x['Stafford_County','Tappahannock'] +
# 	2*x['Warren_County','Tappahannock'] +
# 	105*x['Westmoreland_County','Tappahannock'] +
# 	30*x['York_County','Tappahannock'] <= 3400;
#
# subject to available_hours['Tappahannock','Payroll']:
# 	771*x['Albemarle_County','Tappahannock'] +
# 	28*x['Amherst_County','Tappahannock'] +
# 	737*x['Augusta_County','Tappahannock'] +
# 	40*x['Buckingham_County','Tappahannock'] +
# 	136*x['Caroline_County','Tappahannock'] +
# 	26*x['Charles_City_County','Tappahannock'] +
# 	343*x['Chesterfield_County','Tappahannock'] +
# 	64*x['City_of_Fredericksburg','Tappahannock'] +
# 	264*x['City_of_Richmond','Tappahannock'] +
# 	96*x['Culpeper_County','Tappahannock'] +
# 	33*x['Cumberland_County','Tappahannock'] +
# 	188*x['Dinwiddie_County','Tappahannock'] +
# 	30*x['Essex_County','Tappahannock'] +
# 	228*x['Fauquier_County','Tappahannock'] +
# 	96*x['Fluvanna_County','Tappahannock'] +
# 	97*x['Goochland_County','Tappahannock'] +
# 	88*x['Greene_County','Tappahannock'] +
# 	184*x['Hanover_County','Tappahannock'] +
# 	227*x['Henrico_County','Tappahannock'] +
# 	36*x['Hopewell_County','Tappahannock'] +
# 	127*x['James_City_County','Tappahannock'] +
# 	14*x['King_and_Queen_County','Tappahannock'] +
# 	56*x['King_George_County','Tappahannock'] +
# 	70*x['King_William_County','Tappahannock'] +
# 	114*x['Louisa_County','Tappahannock'] +
# 	32*x['Madison_County','Tappahannock'] +
# 	21*x['Mathews_County','Tappahannock'] +
# 	71*x['Nelson_County','Tappahannock'] +
# 	52*x['New_Kent_County','Tappahannock'] +
# 	136*x['Orange_County','Tappahannock'] +
# 	170*x['Page_County','Tappahannock'] +
# 	148*x['Powhatan_County','Tappahannock'] +
# 	24*x['Prince_George_County','Tappahannock'] +
# 	385*x['Prince_William_County','Tappahannock'] +
# 	8*x['Rappahannock_County','Tappahannock'] +
# 	470*x['Rockbridge_County','Tappahannock'] +
# 	761*x['Rockingham_County','Tappahannock'] +
# 	97*x['Shenandoah_County','Tappahannock'] +
# 	192*x['Spotsylvania_County','Tappahannock'] +
# 	200*x['Stafford_County','Tappahannock'] +
# 	121*x['Warren_County','Tappahannock'] +
# 	17*x['Westmoreland_County','Tappahannock'] +
# 	91*x['York_County','Tappahannock'] <= 5550;
#
# subject to available_hours['Tappahannock','Hiring']:
# 	2806*x['Augusta_County','Tappahannock'] +
# 	408*x['Buckingham_County','Tappahannock'] +
# 	170*x['Caroline_County','Tappahannock'] +
# 	17*x['Chesterfield_County','Tappahannock'] +
# 	60*x['City_of_Fredericksburg','Tappahannock'] +
# 	200*x['Culpeper_County','Tappahannock'] +
# 	480*x['Dinwiddie_County','Tappahannock'] +
# 	680*x['Essex_County','Tappahannock'] +
# 	280*x['Fauquier_County','Tappahannock'] +
# 	150*x['Greene_County','Tappahannock'] +
# 	150*x['Hanover_County','Tappahannock'] +
# 	60*x['James_City_County','Tappahannock'] +
# 	340*x['King_and_Queen_County','Tappahannock'] +
# 	150*x['King_George_County','Tappahannock'] +
# 	60*x['King_William_County','Tappahannock'] +
# 	150*x['Madison_County','Tappahannock'] +
# 	60*x['New_Kent_County','Tappahannock'] +
# 	150*x['Orange_County','Tappahannock'] +
# 	176*x['Page_County','Tappahannock'] +
# 	60*x['Powhatan_County','Tappahannock'] +
# 	60*x['Prince_George_County','Tappahannock'] +
# 	315*x['Prince_William_County','Tappahannock'] +
# 	150*x['Rappahannock_County','Tappahannock'] +
# 	450*x['Rockbridge_County','Tappahannock'] +
# 	3175*x['Rockingham_County','Tappahannock'] +
# 	120*x['Shenandoah_County','Tappahannock'] +
# 	150*x['Spotsylvania_County','Tappahannock'] +
# 	100*x['Stafford_County','Tappahannock'] +
# 	120*x['Westmoreland_County','Tappahannock'] <= 3250;
#
# subject to available_hours['Tappahannock','Marketing']:
# 	96*x['Albemarle_County','Tappahannock'] +
# 	8*x['Amherst_County','Tappahannock'] +
# 	260*x['Augusta_County','Tappahannock'] +
# 	84*x['Buckingham_County','Tappahannock'] +
# 	10*x['Caroline_County','Tappahannock'] +
# 	40*x['Charles_City_County','Tappahannock'] +
# 	144*x['Chesterfield_County','Tappahannock'] +
# 	14*x['Cumberland_County','Tappahannock'] +
# 	160*x['Dinwiddie_County','Tappahannock'] +
# 	200*x['Essex_County','Tappahannock'] +
# 	320*x['Fauquier_County','Tappahannock'] +
# 	8*x['Fluvanna_County','Tappahannock'] +
# 	70*x['Goochland_County','Tappahannock'] +
# 	200*x['Hanover_County','Tappahannock'] +
# 	84*x['Henrico_County','Tappahannock'] +
# 	40*x['King_and_Queen_County','Tappahannock'] +
# 	40*x['King_William_County','Tappahannock'] +
# 	8*x['Louisa_County','Tappahannock'] +
# 	10*x['Mathews_County','Tappahannock'] +
# 	8*x['Nelson_County','Tappahannock'] +
# 	200*x['New_Kent_County','Tappahannock'] +
# 	8*x['Page_County','Tappahannock'] +
# 	22*x['Powhatan_County','Tappahannock'] +
# 	52*x['Prince_George_County','Tappahannock'] +
# 	256*x['Prince_William_County','Tappahannock'] +
# 	226*x['Rockbridge_County','Tappahannock'] +
# 	288*x['Rockingham_County','Tappahannock'] +
# 	4*x['Shenandoah_County','Tappahannock'] +
# 	2*x['Warren_County','Tappahannock'] +
# 	10*x['Westmoreland_County','Tappahannock'] +
# 	10*x['York_County','Tappahannock'] <= 1200;
#
# subject to available_hours['Tappahannock','Merchandising']:
# 	90*x['Albemarle_County','Tappahannock'] +
# 	65*x['Augusta_County','Tappahannock'] +
# 	59*x['Buckingham_County','Tappahannock'] +
# 	55*x['Caroline_County','Tappahannock'] +
# 	15*x['Charles_City_County','Tappahannock'] +
# 	8*x['Chesterfield_County','Tappahannock'] +
# 	70*x['City_of_Fredericksburg','Tappahannock'] +
# 	2*x['City_of_Richmond','Tappahannock'] +
# 	120*x['Culpeper_County','Tappahannock'] +
# 	50*x['Dinwiddie_County','Tappahannock'] +
# 	80*x['Essex_County','Tappahannock'] +
# 	40*x['Fauquier_County','Tappahannock'] +
# 	5*x['Goochland_County','Tappahannock'] +
# 	40*x['Greene_County','Tappahannock'] +
# 	120*x['Hanover_County','Tappahannock'] +
# 	78*x['Henrico_County','Tappahannock'] +
# 	4*x['Hopewell_County','Tappahannock'] +
# 	140*x['James_City_County','Tappahannock'] +
# 	60*x['King_and_Queen_County','Tappahannock'] +
# 	70*x['King_George_County','Tappahannock'] +
# 	60*x['King_William_County','Tappahannock'] +
# 	25*x['Louisa_County','Tappahannock'] +
# 	40*x['Madison_County','Tappahannock'] +
# 	60*x['Mathews_County','Tappahannock'] +
# 	60*x['New_Kent_County','Tappahannock'] +
# 	25*x['Orange_County','Tappahannock'] +
# 	40*x['Page_County','Tappahannock'] +
# 	288*x['Prince_William_County','Tappahannock'] +
# 	130*x['Rappahannock_County','Tappahannock'] +
# 	28*x['Rockbridge_County','Tappahannock'] +
# 	65*x['Rockingham_County','Tappahannock'] +
# 	25*x['Shenandoah_County','Tappahannock'] +
# 	90*x['Spotsylvania_County','Tappahannock'] +
# 	110*x['Stafford_County','Tappahannock'] +
# 	5*x['Warren_County','Tappahannock'] +
# 	40*x['Westmoreland_County','Tappahannock'] +
# 	50*x['York_County','Tappahannock'] <= 1600;

# %%
ampl.setOption('solver', 'cplex')

# %%
# Solve the problem
ampl.solve()
# Out:
# CPLEX 22.1.1: optimal solution; objective 879.749
# 5 simplex iterations

# %%
# Display results
print("Optimal Total Cost:", ampl.getObjective("total_cost").value())
x = ampl.getVariable("x")
print("\nOptimal Assignments:")

# Use .toDict() to convert results to a dictionary
results = x.getValues().toDict()

# Iterate through the results
for (store, office), value in results.items():
    if value > 0.5:  # Check if binary decision variable is "selected"
        print(f"{store} assigned to {office}")
# Out:
# Optimal Total Cost: 879.7489999999999
#
# Optimal Assignments:
# Albemarle_County assigned to Staunton
# Amherst_County assigned to Staunton
# Augusta_County assigned to Staunton
# Buckingham_County assigned to Staunton
# Caroline_County assigned to Tappahannock
# Charles_City_County assigned to Richmond
# Chesterfield_County assigned to Richmond
# City_of_Fredericksburg assigned to Tappahannock
# City_of_Richmond assigned to Richmond
# Culpeper_County assigned to Warrenton
# Cumberland_County assigned to Richmond
# Dinwiddie_County assigned to Richmond
# Essex_County assigned to Tappahannock
# Fauquier_County assigned to Warrenton
# Fluvanna_County assigned to Staunton
# Goochland_County assigned to Richmond
# Greene_County assigned to Staunton
# Hanover_County assigned to Richmond
# Henrico_County assigned to Richmond
# Hopewell_County assigned to Richmond
# James_City_County assigned to Richmond
# King_George_County assigned to Tappahannock
# King_William_County assigned to Tappahannock
# King_and_Queen_County assigned to Tappahannock
# Louisa_County assigned to Richmond
# Madison_County assigned to Warrenton
# Mathews_County assigned to Tappahannock
# Nelson_County assigned to Staunton
# New_Kent_County assigned to Richmond
# Orange_County assigned to Warrenton
# Page_County assigned to Warrenton
# Powhatan_County assigned to Richmond
# Prince_George_County assigned to Richmond
# Prince_William_County assigned to Warrenton
# Rappahannock_County assigned to Warrenton
# Rockbridge_County assigned to Staunton
# Rockingham_County assigned to Staunton
# Shenandoah_County assigned to Warrenton
# Spotsylvania_County assigned to Tappahannock
# Stafford_County assigned to Warrenton
# Warren_County assigned to Warrenton
# Westmoreland_County assigned to Tappahannock
# York_County assigned to Tappahannock
